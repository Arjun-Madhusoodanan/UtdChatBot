# %%
# import aiohttp
# import asyncio
# import pandas as pd
# from bs4 import BeautifulSoup
# from tqdm.asyncio import tqdm
# import nest_asyncio  # Import nest_asyncio
# import time

# # Define the main sitemap URL
# MAIN_SITEMAP_URL = "https://www.utdallas.edu/wp-sitemap.xml"
# CRAWL_DELAY = 30  # UTDallas crawl delay is 30 seconds

# async def fetch(session, url):
#     """Fetch content from a URL asynchronously."""
#     try:
#         async with session.get(url, timeout=10) as response:
#             return await response.text()
#     except Exception as e:
#         print(f"Error fetching {url}: {e}")
#         return None

# async def get_sub_sitemaps():
#     """Get sub-sitemaps from the main sitemap."""
#     async with aiohttp.ClientSession() as session:
#         sitemap_xml = await fetch(session, MAIN_SITEMAP_URL)
#         if not sitemap_xml:
#             return []

#         soup = BeautifulSoup(sitemap_xml, "xml")
#         return [loc.text for loc in soup.find_all("loc")]

# async def get_page_urls(sub_sitemap_url):
#     """Get all page URLs from a sub-sitemap."""
#     async with aiohttp.ClientSession() as session:
#         sitemap_xml = await fetch(session, sub_sitemap_url)
#         if not sitemap_xml:
#             return []

#         soup = BeautifulSoup(sitemap_xml, "xml")
#         return [loc.text for loc in soup.find_all("loc")]

# async def scrape_page(session, url):
#     """Scrape a single page."""
#     html = await fetch(session, url)
#     if not html:
#         return None

#     soup = BeautifulSoup(html, "html.parser")
#     title = soup.title.string if soup.title else "No Title"
#     content = " ".join([p.get_text(strip=True) for p in soup.find_all("p")])

#     return {"URL": url, "Title": title, "Content": content}

# async def scrape_all():
#     """Scrape all pages with controlled concurrency."""
#     sub_sitemaps = await get_sub_sitemaps()

#     # Get all page URLs from sub-sitemaps
#     page_urls = []
#     for sub_sitemap in tqdm(sub_sitemaps, desc="Extracting page URLs"):
#         page_urls.extend(await get_page_urls(sub_sitemap))

#     print(f"Total URLs found: {len(page_urls)}")

#     # Scrape pages in batches with delay
#     scraped_data = []
#     async with aiohttp.ClientSession() as session:
#         for i in range(0, len(page_urls), 20):  # Scrape in batches of 10
#             batch_urls = page_urls[i : i + 20]

#             tasks = [scrape_page(session, url) for url in batch_urls]
#             results = await tqdm.gather(*tasks)

#             scraped_data.extend(filter(None, results))

#             # Save to CSV incrementally
#             df = pd.DataFrame(scraped_data)
#             df.to_csv("utdallas_scraped_data.csv", index=False)

#             print(f"✅ Saved {len(scraped_data)} records to CSV")
#             time.sleep(CRAWL_DELAY)  # Respect 30s delay

#     print("🎉 Scraping complete!")

# nest_asyncio.apply()  # Apply nest_asyncio patch
# # Run the scraping process
# asyncio.run(scrape_all())

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

# Sitemap URL
sitemap_url = "https://jindal.utdallas.edu/sitemap/"

# Step 1: Fetch the Sitemap Page
response = requests.get(sitemap_url, headers={"User-Agent": "Mozilla/5.0"})
if response.status_code != 200:
    print("Failed to fetch the sitemap")
    exit()

soup = BeautifulSoup(response.text, "html.parser")

# Step 2: Extract URLs from <a> tags
urls = [a["href"] for a in soup.find_all("a", href=True) if a["href"].startswith("https")]

# Step 3: Visit Each URL and Extract Structured Data
data = []
for idx, url in enumerate(urls):  # Limit to first 10 URLs for testing
    try:
        print(f"Processing [{idx+1}/{len(urls)}]: {url}")

        # Fetch page content
        page_response = requests.get(url, headers={"User-Agent": "Mozilla/5.0"}, timeout=5)
        if page_response.status_code != 200:
            print(f"Skipping {url} (Failed to fetch)")
            continue

        page_soup = BeautifulSoup(page_response.text, "html.parser")

        # Extract Page Title (Main topic)
        main_title = page_soup.title.string.strip() if page_soup.title else "No Title Found"

        # Extract Sections (Headings and Content)
        for heading in page_soup.find_all(["h1", "h2", "h3"]):  # Extract main & subheadings
            section_title = heading.get_text(strip=True)
            content = []

            # Get all text after this heading until the next heading
            for sibling in heading.find_next_siblings():
                if sibling.name and sibling.name.startswith("h"):  # Stop at next heading
                    break
                if sibling.name in ["p", "div", "li"]:
                    text = sibling.get_text(strip=True)
                    if text and len(text) > 50:  # Avoid short/noisy text
                        content.append(text)

            if content:
                data.append({"URL": url, "MainTitle": main_title, "SectionTitle": section_title, "Content": " ".join(content)})

        time.sleep(1)  # Avoid overwhelming the server

    except Exception as e:
        print(f"Error processing {url}: {e}")

# Step 4: Save Data to CSV
df = pd.DataFrame(data)
df.to_csv("jindal_sitemap_lex_all.csv", index=False, encoding="utf-8")

print("✅ Data extraction complete! Saved to 'jindal_sitemap_lex.csv'")
# Out:
# Processing [1/1120]: https://utdallas.edu
# Processing [2/1120]: https://jindal.utdallas.edu/staff-list/
# Processing [3/1120]: https://galaxy.utdallas.edu/
# Processing [4/1120]: https://www.utdallas.edu/directory
# Processing [5/1120]: https://elearning.utdallas.edu/
# Processing [6/1120]: https://map.concept3d.com/?id=1772#!m/435245?ce/42138?bm/
# Processing [7/1120]: https://www.utdallas.edu/academics/calendar/
# Processing [8/1120]: https://coursebook.utdallas.edu/
# Processing [9/1120]: https://jindal.utdallas.edu/admission-requirements/
# Processing [10/1120]: https://jindal.utdallas.edu/request-information/
# Processing [11/1120]: https://jindal.utdallas.edu/about-the-jindal-school-of-management/
# Processing [12/1120]: https://jindal.utdallas.edu/about-the-jindal-school-of-management/
# Processing [13/1120]: https://jindal.utdallas.edu/about-the-jindal-school-of-management/community-engagement/
# Processing [14/1120]: https://jindal.utdallas.edu/conferences/
# Processing [15/1120]: https://jindal.utdallas.edu/about-the-jindal-school-of-management/contact/
# Processing [16/1120]: https://jindal.utdallas.edu/about-the-jindal-school-of-management/school-leadership/
# Processing [17/1120]: https://jindal.utdallas.edu/about-the-jindal-school-of-management/message-dean/
# Processing [18/1120]: https://jindal.utdallas.edu/about-the-jindal-school-of-management/naveen-jindal/
# Processing [19/1120]: https://jindal.utdallas.edu/about-the-jindal-school-of-management/business-school-rankings/
# Processing [20/1120]: https://jindal.utdallas.edu/about-the-jindal-school-of-management/student-experience/
# Processing [21/1120]: https://jindal.utdallas.edu/about-the-jindal-school-of-management/pm/
# Processing [22/1120]: https://managementmagazine.utdallas.edu
# Processing [23/1120]: https://jindal.utdallas.edu/academics/
# Processing [24/1120]: https://jindal.utdallas.edu/academics/
# Processing [25/1120]: https://jindal.utdallas.edu/undergraduate-programs/
# Processing [26/1120]: https://jindal.utdallas.edu/masters-programs/
# Processing [1100/1120]: https://execed.utdallas.edu/
# Processing [1101/1120]: https://jindal.utdallas.edu/certificate-programs/
# Processing [1102/1120]: https://jindal.utdallas.edu/centers-of-excellence/
# Processing [1103/1120]: https://jindal.utdallas.edu/staff-list/
# Processing [1104/1120]: https://jindal.utdallas.edu/about-the-jindal-school-of-management/
# Processing [1105/1120]: https://jindal.utdallas.edu/advising/
# Processing [1106/1120]: https://jindal.utdallas.edu/career-management-center/
# Processing [1107/1120]: https://jindal.utdallas.edu/alumni/
# Processing [1108/1120]: https://jindal.utdallas.edu/external-relations/
# Processing [1109/1120]: https://jindal.utdallas.edu/faculty/
# Processing [1110/1120]: https://jsom.utdallas.edu/list-of-published-works
# Processing [1111/1120]: https://jindal.utdallas.edu/external-relations/news-stories/
# Processing [1112/1120]: https://www.facebook.com/jindal.utdallas
# Processing [1113/1120]: https://twitter.com/jindal_utdallas
# Skipping https://twitter.com/jindal_utdallas (Failed to fetch)
# Processing [1114/1120]: https://instagram.com/jindal_utdallas
# Skipping https://instagram.com/jindal_utdallas (Failed to fetch)
# Processing [1115/1120]: https://www.linkedin.com/school/university-of-texas-at-dallas---naveen-jindal-school-of-management/mycompany/?viewAsMember=true
# Processing [1116/1120]: https://www.youtube.com/channel/UCoUw4cCn3EFg2RIQKJt8aSA
# Processing [1117/1120]: https://jindal.utdallas.edu/sitemap/
# Processing [1118/1120]: https://jindal.utdallas.edu/content-owners/
# Processing [1119/1120]: https://jindal.utdallas.edu/privacy-policy/
# Processing [1120/1120]: https://www.utdallas.edu/about-us/accessibility/
# ✅ Data extraction complete! Saved to 'jindal_sitemap_lex.csv'

# %%
# # Step 4: Save data to CSV
# df = pd.DataFrame(scraped_data)
# df.to_csv("utdallas_scraped_data.csv", index=False)

# print("Scraping completed! Data saved to utdallas_scraped_data.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-e828ff5fe695> in <cell line: 0>()
#       1 # Step 4: Save data to CSV
# ----> 2 df = pd.DataFrame(scraped_data)
#       3 df.to_csv("utdallas_scraped_data.csv", index=False)
#       4
#       5 print("Scraping completed! Data saved to utdallas_scraped_data.csv")
#
# NameError: name 'scraped_data' is not defined

# %%
df.head(50)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-61c774354124> in <cell line: 0>()
# ----> 1 df.head(50)
#
# NameError: name 'df' is not defined

# %%
from google.colab import files
# files.download("utdallas_scraped_data.csv")
files.download("jindal_sitemap_lex_all.csv")

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

# Base URL to track internal links
base_url = "https://jindal.utdallas.edu"

# Track visited URLs to avoid duplicates
visited_urls = set()

# Data storage
data = []

def extract_data(url):
    """Fetch page, extract titles, content, and find more links recursively."""
    if url in visited_urls or not url.startswith(base_url):  # Skip if already visited or external
        return

    print(f"Processing: {url}")
    visited_urls.add(url)

    try:
        # Fetch page content
        response = requests.get(url, headers={"User-Agent": "Mozilla/5.0"}, timeout=5)
        if response.status_code != 200:
            print(f"Skipping {url} (Failed to fetch)")
            return

        soup = BeautifulSoup(response.text, "html.parser")

        # Extract Page Title (Main topic)
        main_title = soup.title.string.strip() if soup.title else "No Title Found"

        # Extract Sections (Headings and Content)
        for heading in soup.find_all(["h1", "h2", "h3"]):  # Extract main & subheadings
            section_title = heading.get_text(strip=True)
            content = []

            # Get all text after this heading until the next heading
            for sibling in heading.find_next_siblings():
                if sibling.name and sibling.name.startswith("h"):  # Stop at next heading
                    break
                if sibling.name in ["p", "div", "li"]:
                    text = sibling.get_text(strip=True)
                    if text and len(text) > 50:  # Avoid short/noisy text
                        content.append(text)

            if content:
                data.append({"URL": url, "MainTitle": main_title, "SectionTitle": section_title, "Content": " ".join(content)})

        # Find all sub-links on the page and process them recursively
        for link in soup.find_all("a", href=True):
            sub_url = link["href"]
            if sub_url.startswith("/"):  # Convert relative URLs to absolute
                sub_url = base_url + sub_url
            if sub_url.startswith(base_url) and sub_url not in visited_urls:
                extract_data(sub_url)  # Recursive call

        time.sleep(1)  # Avoid overwhelming the server

    except Exception as e:
        print(f"Error processing {url}: {e}")

# Step 1: Fetch the main sitemap page
sitemap_url = base_url + "/sitemap/"
response = requests.get(sitemap_url, headers={"User-Agent": "Mozilla/5.0"})
if response.status_code != 200:
    print("Failed to fetch the sitemap")
    exit()

soup = BeautifulSoup(response.text, "html.parser")

# Step 2: Extract main URLs from the sitemap
main_urls = [a["href"] for a in soup.find_all("a", href=True) if a["href"].startswith("https")]

# Step 3: Start the recursive extraction from the main URLs
for main_url in main_urls[:10]:  # Limit initial run for testing
    extract_data(main_url)

# Step 4: Save Data to CSV
df = pd.DataFrame(data)
df.to_csv("jindal_sitemap_recursive.csv", index=False, encoding="utf-8")

print("✅ Full recursive data extraction complete! Saved to 'jindal_sitemap_recursive.csv'")
# Out:
# Processing: https://jindal.utdallas.edu/staff-list/
# Processing: https://jindal.utdallas.edu/admission-requirements/
# Processing: https://jindal.utdallas.edu/request-information/
# Processing: https://jindal.utdallas.edu/jindal/about-the-jindal-school-of-management/business-school-rankings
# Processing: https://jindal.utdallas.edu/jindal/news
# Processing: https://jindal.utdallas.edu/jindal/career-management-center/
# Processing: https://jindal.utdallas.edu/jindal/calendar
# Processing: https://jindal.utdallas.edu/jindal/external-relations/
# Processing: https://jindal.utdallas.edu/jindal/about-the-jindal-school-of-management/community-engagement/
# Processing: https://jindal.utdallas.edu/jindal/giving-jsom/
# Processing: https://jindal.utdallas.edu/about-the-jindal-school-of-management/
# Processing: https://jindal.utdallas.edu/about-the-jindal-school-of-management/community-engagement/
# Processing: https://jindal.utdallas.edu/conferences/
# Processing: https://jindal.utdallas.edu/about-the-jindal-school-of-management/contact/
# Processing: https://jindal.utdallas.edu/about-the-jindal-school-of-management/school-leadership/
# Processing: https://jindal.utdallas.edu/about-the-jindal-school-of-management/message-dean/
# Processing: https://jindal.utdallas.edu/about-the-jindal-school-of-management/naveen-jindal/
# Processing: https://jindal.utdallas.edu/about-the-jindal-school-of-management/business-school-rankings/
# Processing: https://jindal.utdallas.edu/about-the-jindal-school-of-management/student-experience/
# Processing: https://jindal.utdallas.edu/about-the-jindal-school-of-management/pm/
# Processing: https://jindal.utdallas.edu/academics/
# Processing: https://jindal.utdallas.edu/undergraduate-programs/
# Processing: https://jindal.utdallas.edu/masters-programs/
# Processing: https://jindal.utdallas.edu/phd-programs/
# Processing: https://jindal.utdallas.edu/certificate-programs/
# Processing: https://jindal.utdallas.edu/honors-programs/
# Processing: https://jindal.utdallas.edu/faculty/
# Processing: https://jindal.utdallas.edu/faculty-research/
# Processing: https://jindal.utdallas.edu/student-resources/
# Processing: https://jindal.utdallas.edu/student-resources
# Processing: https://jindal.utdallas.edu/advising/
# Processing: https://jindal.utdallas.edu/student-resources/business-cards/
# Processing: https://jindal.utdallas.edu/student-resources/business-communication-center/
# Processing: https://jindal.utdallas.edu/about-the-jindal-school-of-management/business-competitions/
# Processing: https://jindal.utdallas.edu/career-management-center/
# Processing: https://jindal.utdallas.edu/student-resources/comet-closet/
# Processing: https://jindal.utdallas.edu/student-resources/deans-council/
# Processing: https://jindal.utdallas.edu/faculty-mentoring/
# Processing: https://jindal.utdallas.edu/faq/
# Processing: https://jindal.utdallas.edu/student-resources/finance-lab/
# Processing: https://jindal.utdallas.edu/student-resources/grammarly-quinncia/
# Processing: https://jindal.utdallas.edu/student-resources/labs/
# Processing: https://jindal.utdallas.edu/student-resources/living-learning-community/
# Processing: https://jindal.utdallas.edu/student-resources/lockers/
# Processing: https://jindal.utdallas.edu/student-resources/neurodiversity/
# Processing: https://jindal.utdallas.edu/student-resources/scholarships/
# Processing: https://jindal.utdallas.edu/student-resources/special-event-room-reservation/
# Processing: https://jindal.utdallas.edu/student-resources/student-organizations/
# Processing: https://jindal.utdallas.edu/student-resources/study-abroad-programs/
# Processing: https://jindal.utdallas.edu/student-resources/assistantships/
# Processing: https://jindal.utdallas.edu/student-resources/tech-support/
# Processing: https://jindal.utdallas.edu/undergraduate-programs/utdserv/
# Processing: https://jindal.utdallas.edu/alumni/
# Processing: https://jindal.utdallas.edu/alumni/alumni-events/
# Processing: https://jindal.utdallas.edu/alumni/involvement/
# Processing: https://jindal.utdallas.edu/alumni/mentor-volunteer-opportunities/
# Processing: https://jindal.utdallas.edu/alumni/alumni-chapters/
# Processing: https://jindal.utdallas.edu/alumni/alumni-contacts/
# Processing: https://jindal.utdallas.edu/centers-of-excellence/
# Processing: https://jindal.utdallas.edu/centers-of-excellence/lboe/
# Processing: https://jindal.utdallas.edu/centers-of-excellence/cfsi/
# Processing: https://jindal.utdallas.edu/centers-of-excellence/cgb/
# Processing: https://jindal.utdallas.edu/centers-of-excellence/healthcare/
# Processing: https://jindal.utdallas.edu/centers-of-excellence/citm/
# Processing: https://jindal.utdallas.edu/centers-of-excellence/c4isn/
# Processing: https://jindal.utdallas.edu/centers-of-excellence/iaep/
# Processing: https://jindal.utdallas.edu/centers-of-excellence/pro-sales/
# Processing: https://jindal.utdallas.edu/centers-of-excellence/retail-innovation-strategy-excellence/
# Processing: https://jindal.utdallas.edu/centers-of-excellence/fd-tech-center/
# Processing: https://jindal.utdallas.edu/centers-of-excellence/weitzman-institute-real-estate/
# Processing: https://jindal.utdallas.edu/centers-of-excellence/iecg/
# Processing: https://jindal.utdallas.edu/centers-of-excellence/icdria/
# Processing: https://jindal.utdallas.edu/centers-of-excellence/morris-hite-center-for-marketing/
# Processing: https://jindal.utdallas.edu/centers-of-excellence/cgb/sustainable-global-business-initiative/
# Processing: https://jindal.utdallas.edu/admission-requirements/undergraduate/
# Processing: https://jindal.utdallas.edu/admission-requirements/masters/
# Processing: https://jindal.utdallas.edu/phd-programs/admission-requirements/
# Processing: https://jindal.utdallas.edu/admission-requirements/admission-resources/
# Processing: https://jindal.utdallas.edu/admission-requirements/admission-resources/academic-documents/
# Processing: https://jindal.utdallas.edu/admission-requirements/admission-resources/english-waiver/
# Processing: https://jindal.utdallas.edu/admission-requirements/admission-resources/gmat-codes/
# Processing: https://jindal.utdallas.edu
# Processing: https://jindal.utdallas.edu/calendar
# Processing: https://jindal.utdallas.edu/external-relations/
# Processing: https://jindal.utdallas.edu/external-relations/news-stories/
# Processing: https://jindal.utdallas.edu/external-relations/corporate-relations/
# Processing: https://jindal.utdallas.edu/sitemap/
# Processing: https://jindal.utdallas.edu/2015-07/
# Processing: https://jindal.utdallas.edu/content-owners/
# Processing: https://jindal.utdallas.edu/about-the-jindal-school-of-management/phd-student-experience/
# Processing: https://jindal.utdallas.edu/about-the-jindal-school-of-management/undergrad-student-experience/
# Processing: https://jindal.utdallas.edu/about-the-jindal-school-of-management/master-student-experience/
# Processing: https://jindal.utdallas.edu/about-the-jindal-school-of-management/mba-student-experience/
# Processing: https://jindal.utdallas.edu/about-the-jindal-school-of-management/executive-education-student-experience/
# Processing: https://jindal.utdallas.edu/about-the-jindal-school-of-management/jindal-undergraduate-research-scholar/
# Processing: https://jindal.utdallas.edu/about-the-jindal-school-of-management/jindal-undergraduate-research-scholar-home/
# Processing: https://jindal.utdallas.edu/about-the-jindal-school-of-management/jindal-undergraduate-research-scholar-research/
# Processing: https://jindal.utdallas.edu/about-the-jindal-school-of-management/jindal-undergraduate-scholar-research-events/
# Processing: https://jindal.utdallas.edu/news/technology-meets-sustainability-at-jindal-school-conference/
# Processing: https://jindal.utdallas.edu/news/
# Processing: https://jindal.utdallas.edu/./news/academics-news-category/
# Processing: https://jindal.utdallas.edu/./news/students-news-category/
# Processing: https://jindal.utdallas.edu/./news/events-news-category/
# Processing: https://jindal.utdallas.edu/./news/corporate-news-category/
# Processing: https://jindal.utdallas.edu/./news/faculty-research-news-category/
# Processing: https://jindal.utdallas.edu/./news/
# Processing: https://jindal.utdallas.edu/news
# Processing: https://jindal.utdallas.edu/news/advancing-marketing-science-key-discussions-from-the-jindal-schools-2025-bass-forms-conference/
# Processing: https://jindal.utdallas.edu/./alumni-spotlights/
# Processing: https://jindal.utdallas.edu/./testimonials/
# Processing: https://jindal.utdallas.edu/./newsletters/
# Processing: https://jindal.utdallas.edu/newsletters/
# Processing: https://jindal.utdallas.edu/jindal/jindal-school-now/
# Processing: https://jindal.utdallas.edu/mba/voices/mba-g-o-a-t-podcast/
# Skipping https://jindal.utdallas.edu/mba/voices/mba-g-o-a-t-podcast/ (Failed to fetch)
# Processing: https://jindal.utdallas.edu/jindal-school-now
# Processing: https://jindal.utdallas.edu/jindal/finance-newsletter/
# Processing: https://jindal.utdallas.edu/finance-newsletter
# Processing: https://jindal.utdallas.edu/newsletters/finance-newsletter/finance-newsletter-spring-summer-2024/
# Processing: https://jindal.utdallas.edu/
# Processing: https://jindal.utdallas.edu/biz-ai-conference-ai-applications-in-business-research/
# Processing: https://jindal.utdallas.edu/privacy-policy/
# Processing: https://jindal.utdallas.edu/alumni/jsomreunion/
# Processing: https://jindal.utdallas.edu/jindal/about-the-jindal-school-of-management/
# Processing: https://jindal.utdallas.edu/accounting/
# Processing: https://jindal.utdallas.edu/phd-programs/management-science/accounting/
# Processing: https://jindal.utdallas.edu/phd-programs/management-science/
# Processing: https://jindal.utdallas.edu/phd-programs/management-science/finance/
# Processing: https://jindal.utdallas.edu/phd-programs/management-science/information-systems/
# Processing: https://jindal.utdallas.edu/phd-programs/management-science/marketing/
# Processing: https://jindal.utdallas.edu/phd-programs/management-science/operations-management/
# Processing: https://jindal.utdallas.edu/phd-programs/management-science/degree-plan/
# Processing: https://jindal.utdallas.edu/advising/degree-plans/
# Processing: https://jindal.utdallas.edu/advising/forms/
# Processing: https://jindal.utdallas.edu/advising/registration/
# Processing: https://jindal.utdallas.edu/advising/new-students-information/
# Processing: https://jindal.utdallas.edu/faq/#graduate-advising&gsc.tab=0
# Processing: https://jindal.utdallas.edu/faq
# Processing: https://jindal.utdallas.edu/admission-requirements-procedures
# Processing: https://jindal.utdallas.edu/./faq/
# Processing: https://jindal.utdallas.edu/bs-human-resource-management-faq
# Processing: https://jindal.utdallas.edu/bs-marketing-faq
# Processing: https://jindal.utdallas.edu/jindal/about-the-jindal-school-of-management/pm/?_ga=2.44612516.1695136065.1682341571-532804723.1657832421
# Processing: https://jindal.utdallas.edu/bs-its-faq
# Processing: https://jindal.utdallas.edu/jindal/student-resources/mis-lab/
# Processing: https://jindal.utdallas.edu/jindal/student-resources/business-communication-center/
# Processing: https://jindal.utdallas.edu/student-resources/business-communication-center/workshops/
# Processing: https://jindal.utdallas.edu/student-resources/business-communication-center/policies-and-faq/
# Processing: https://jindal.utdallas.edu/student-resources/business-communication-center/additional-resources/
# Processing: https://jindal.utdallas.edu/jindal/files/2022/06/quinncia-action-verb-list.pdf
# Processing: https://jindal.utdallas.edu/jindal/files/2021/03/bcc_writing_abstracts.pdf
# Processing: https://jindal.utdallas.edu/jindal/files/2024/10/essay_questions.pdf
# Processing: https://jindal.utdallas.edu/jindal/files/2021/03/apa_format_cover_page_example.pdf
# Processing: https://jindal.utdallas.edu/jindal/files/2022/09/apa-format-and-cover-page-template.docx
# Processing: https://jindal.utdallas.edu/jindal/files/2021/03/bcc_bulleted_lists.pdf
# Processing: https://jindal.utdallas.edu/jindal/files/2021/09/cover-letter-template.docx
# Processing: https://jindal.utdallas.edu/jindal/files/2021/03/apa_citing_referencing.pdf
# Processing: https://jindal.utdallas.edu/jindal/files/2022/09/paraphrasing.pdf
# Processing: https://jindal.utdallas.edu/student-resources/business-communication-center/citing-generative-ai/
# Processing: https://jindal.utdallas.edu/accounting/program-resources/accounting-tutoring-lab/
# Skipping https://jindal.utdallas.edu/accounting/program-resources/accounting-tutoring-lab/ (Failed to fetch)
# Processing: https://jindal.utdallas.edu/jindal/student-resources/finance-lab/
# Processing: https://jindal.utdallas.edu/student-resources/finance-lab/database-technology/
# Processing: https://jindal.utdallas.edu/student-resources/finance-lab/hours-policies/
# Processing: https://jindal.utdallas.edu/student-resources/finance-lab/events/
# Processing: https://jindal.utdallas.edu/student-resources/finance-lab/projects/
# Processing: https://jindal.utdallas.edu/student-resources/finance-lab/stock-trading-competitions/
# Processing: https://jindal.utdallas.edu/student-resources/finance-lab/our-team/
# Processing: https://jindal.utdallas.edu/testimonials/finance-lab-testimonials/rushab-kachhara-msf-fall-2020/
# Processing: https://jindal.utdallas.edu/finance-lab-testimonials
# Processing: https://jindal.utdallas.edu/testimonials/finance-lab-testimonials/priya-rupramka-msf-fall-2021/
# Processing: https://jindal.utdallas.edu/testimonials/finance-lab-testimonials/akash-singh-verma-msf-spring-2022/
# Processing: https://jindal.utdallas.edu/testimonials/finance-lab-testimonials/rose-shaojun-wang-msf-spring-2022/
# Processing: https://jindal.utdallas.edu/testimonials/finance-lab-testimonials/hui-vivienne-zhi-msf-spring-2020/
# Processing: https://jindal.utdallas.edu/testimonials/finance-lab-testimonials/ayushi-gupta-msf-fall-2019/
# Processing: https://jindal.utdallas.edu/jindal/request-information/
# Processing: https://jindal.utdallas.edu/request-information
# Processing: https://jindal.utdallas.edu/sms-policy/
# Processing: https://jindal.utdallas.edu/forms/request-information/
# Processing: https://jindal.utdallas.edu/news/global-leadership-mba-program-earns-two-new-online-ranking-recognitions/
# Processing: https://jindal.utdallas.edu/students-news-category
# Processing: https://jindal.utdallas.edu/news/new-jindal-school-lab-harnesses-the-power-of-ai/
# Processing: https://jindal.utdallas.edu/author/jrm014010/
# Processing: https://jindal.utdallas.edu/news/researcher-honors-his-father-though-his-healthcare-work/
# Processing: https://jindal.utdallas.edu/jindal/
# Skipping https://jindal.utdallas.edu/jindal/ (Failed to fetch)
# Processing: https://jindal.utdallas.edu/jindal/faculty/mehmet-ayvaci
# Skipping https://jindal.utdallas.edu/jindal/faculty/mehmet-ayvaci (Failed to fetch)
# Processing: https://jindal.utdallas.edu/tag/bs-healthcare-management/
# Processing: https://jindal.utdallas.edu/blog/student-spotlight-nnamdi-edeoga/
# Processing: https://jindal.utdallas.edu/blog/
# Processing: https://jindal.utdallas.edu/blog
# Processing: https://jindal.utdallas.edu/blog/5-reasons-to-study-risk-management-and-cyber-security-at-ut-dallas/
# Processing: https://jindal.utdallas.edu/student-life-blog
# Processing: https://jindal.utdallas.edu/./blog/
# Processing: https://jindal.utdallas.edu/author/jindalschool39/
# Processing: https://jindal.utdallas.edu/newsletters/jindal-school-now/jindal-school-now-january-2025/
# Processing: https://jindal.utdallas.edu/news/scholarship-breakfast-highlights-alumnus-success-story-and-endowment-announcement/
# Processing: https://jindal.utdallas.edu/jindal/external-relations/scholarship-breakfast/
# Processing: https://jindal.utdallas.edu/external-relations/advisory-council/
# Processing: https://jindal.utdallas.edu/external-relations/scholarship-breakfast/
# Processing: https://jindal.utdallas.edu/centers-of-excellence/fd-tech-center/organization/
# Processing: https://jindal.utdallas.edu/centers-of-excellence/fd-tech-center/contact-fd-tech-center/
# Processing: https://jindal.utdallas.edu/jindal/centers-of-excellence/fd-tech-center/research
# Processing: https://jindal.utdallas.edu/centers-of-excellence/c4isn/professional-certificate-supply-chain/
# Processing: https://jindal.utdallas.edu/centers-of-excellence/c4isn/lean-six-sigma-certificate/
# Processing: https://jindal.utdallas.edu/centers-of-excellence/c4isn/contact/
# Processing: https://jindal.utdallas.edu/execed/product-lifecycle-scm/
# Skipping https://jindal.utdallas.edu/execed/product-lifecycle-scm/ (Failed to fetch)
# Processing: https://jindal.utdallas.edu/jindal/centers-of-excellence/c4isn/research/
# Processing: https://jindal.utdallas.edu/jindal/centers-of-excellence/c4isn/
# Processing: https://jindal.utdallas.edu/jindal/files/2021/02/C4iSN-Brochure.pdf
# Processing: https://jindal.utdallas.edu/jindal/files/2021/02/Product-Life-Cycle-Supply-Chain-Management.pdf
# Processing: https://jindal.utdallas.edu/jindal/files/2021/02/Industry-Viewpoint.pdf
# Processing: https://jindal.utdallas.edu/jindal/centers-of-excellence/c4isn/professional-certificate-supply-chain/
# Processing: https://jindal.utdallas.edu/jindal/centers-of-excellence/c4isn/lean-six-sigma-certificate/
# Processing: https://jindal.utdallas.edu/jindal/centers-of-excellence/c4isn/contact/
# Processing: https://jindal.utdallas.edu/centers-of-excellence/cgb/initiatives/
# Processing: https://jindal.utdallas.edu/centers-of-excellence/cgb/research/
# Processing: https://jindal.utdallas.edu/centers-of-excellence/cgb/events/
# Processing: https://jindal.utdallas.edu/centers-of-excellence/cgb/advisory-board/
# Processing: https://jindal.utdallas.edu/centers-of-excellence/cgb/faculty-alumni/
# Processing: https://jindal.utdallas.edu/centers-of-excellence/cgb/giving/
# Processing: https://jindal.utdallas.edu/centers-of-excellence/cgb/contact/
# Processing: https://jindal.utdallas.edu/osim/bs-global-business/
# Processing: https://jindal.utdallas.edu/jindal/admission-requirements/undergraduate/
# Processing: https://jindal.utdallas.edu/student-resources/deans-council/undergraduate/
# Processing: https://jindal.utdallas.edu/student-resources/deans-council/graduate/
# Processing: https://jindal.utdallas.edu/student-resources/deans-council/owlie-awards/
# Processing: https://jindal.utdallas.edu/student-resources/deans-council/reach-us/
# Processing: https://jindal.utdallas.edu/blog/congratulations-2024-owlie-winners/
# Processing: https://jindal.utdallas.edu/rotator/wise-with-great-potential/
# Processing: https://jindal.utdallas.edu/rotator
# Processing: https://jindal.utdallas.edu/rotator/heart-assocation-honors-associate-dean/
# Processing: https://jindal.utdallas.edu/jindal/faculty/diane-mcnulty
# Skipping https://jindal.utdallas.edu/jindal/faculty/diane-mcnulty (Failed to fetch)
# Processing: https://jindal.utdallas.edu/jindal/external-relations/jindal-young-scholars-program/
# Processing: https://jindal.utdallas.edu/news/healthcare-emba-at-jindal-school-equips-future-healthcare-leaders/
# Processing: https://jindal.utdallas.edu/jindal/faculty/robert-hicks
# Skipping https://jindal.utdallas.edu/jindal/faculty/robert-hicks (Failed to fetch)
# Processing: https://jindal.utdallas.edu/tag/executive-education/
# Processing: https://jindal.utdallas.edu/news/jindal-school-launches-certificate-to-address-need-for-sustainability-education-in-aviation-and-travel/
# Processing: https://jindal.utdallas.edu/certificate-programs/professional/professional-certificate-in-sustainability-strategy-and-management-in-aviation/
# Processing: https://jindal.utdallas.edu/certificate-programs/professional/
# Processing: https://jindal.utdallas.edu/certificate-programs/academic/
# Processing: https://jindal.utdallas.edu/infosystems/certificate-programs/enterprise-systems/
# Skipping https://jindal.utdallas.edu/infosystems/certificate-programs/enterprise-systems/ (Failed to fetch)
# Processing: https://jindal.utdallas.edu/osim/program-resources/healthcare-certificates/healthcare-it/
# Processing: https://jindal.utdallas.edu/author/glendavosburgh/
# Processing: https://jindal.utdallas.edu/news/business-analytics-conference-at-jindal-school-equips-academics-for-rapid-change/
# Processing: https://jindal.utdallas.edu/jindal/faculty/gaurav-shekhar
# Skipping https://jindal.utdallas.edu/jindal/faculty/gaurav-shekhar (Failed to fetch)
# Processing: https://jindal.utdallas.edu/jindal/faculty/vatsal-maru
# Skipping https://jindal.utdallas.edu/jindal/faculty/vatsal-maru (Failed to fetch)
# Processing: https://jindal.utdallas.edu/jindal/faculty/prajakti-akarte
# Skipping https://jindal.utdallas.edu/jindal/faculty/prajakti-akarte (Failed to fetch)
# Processing: https://jindal.utdallas.edu/tag/bs-business-analytics/
# Processing: https://jindal.utdallas.edu/tag/information-systems/
# Processing: https://jindal.utdallas.edu/news/professor-eric-zheng-wins-iss-distinguished-fellow-award/
# Processing: https://jindal.utdallas.edu/news/jindal-school-researchers-win-best-paper-for-human-ai-sales-model/
# Processing: https://jindal.utdallas.edu/jindal/faculty/howard-dover
# Skipping https://jindal.utdallas.edu/jindal/faculty/howard-dover (Failed to fetch)
# Processing: https://jindal.utdallas.edu/jindal/faculty/khai-chiong
# Skipping https://jindal.utdallas.edu/jindal/faculty/khai-chiong (Failed to fetch)
# Processing: https://jindal.utdallas.edu/tag/center-for-professional-sales/
# Processing: https://jindal.utdallas.edu/news/sales-students-score-top-wins-at-annual-competition/
# Processing: https://jindal.utdallas.edu/author/imherr/
# Processing: https://jindal.utdallas.edu/news/texas-business-hall-of-fame-scholars-began-with-bright-ideas-in-the-food-biz/
# Processing: https://jindal.utdallas.edu/jindal/news/jindal-school-students-earn-scholar-award-for-rolling-with-the-punches
# Processing: https://jindal.utdallas.edu/mba/
# Processing: https://jindal.utdallas.edu/mba/career-outcomes/
# Skipping https://jindal.utdallas.edu/mba/career-outcomes/ (Failed to fetch)
# Processing: https://jindal.utdallas.edu/mba/academics/mba-concentrations/
# Skipping https://jindal.utdallas.edu/mba/academics/mba-concentrations/ (Failed to fetch)
# Processing: https://jindal.utdallas.edu/mba/academics/double-ms-mba-degree/
# Skipping https://jindal.utdallas.edu/mba/academics/double-ms-mba-degree/ (Failed to fetch)
# Processing: https://jindal.utdallas.edu/mba/flexible-programs/
# Skipping https://jindal.utdallas.edu/mba/flexible-programs/ (Failed to fetch)
# Processing: https://jindal.utdallas.edu/mba/connect-with-us
# Processing: https://jindal.utdallas.edu/advising/graduation/
# Processing: https://jindal.utdallas.edu/advising/policies/
# Processing: https://jindal.utdallas.edu/advising/jsom-waitlist/
# Processing: https://jindal.utdallas.edu/advising/connect-with-us/
# Processing: https://jindal.utdallas.edu/accounting/ms-accounting-cohort/
# Error processing https://jindal.utdallas.edu/accounting/ms-accounting-cohort/: HTTPSConnectionPool(host='acccounting.utdallas.edu', port=443): Max retries exceeded with url: /ms-accounting-cohort (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7d9c11dc3f90>: Failed to resolve 'acccounting.utdallas.edu' ([Errno -2] Name or service not known)"))
# Processing: https://jindal.utdallas.edu/infosystems/ms-business-analytics-cohort/
# Skipping https://jindal.utdallas.edu/infosystems/ms-business-analytics-cohort/ (Failed to fetch)
# Processing: https://jindal.utdallas.edu/infosystems/ms-business-analytics-online/
# Skipping https://jindal.utdallas.edu/infosystems/ms-business-analytics-online/ (Failed to fetch)
# Processing: https://jindal.utdallas.edu/fin/ms-finance-cohort/
# Skipping https://jindal.utdallas.edu/fin/ms-finance-cohort/ (Failed to fetch)
# Processing: https://jindal.utdallas.edu/fin/ms-ftec/
# Skipping https://jindal.utdallas.edu/fin/ms-ftec/ (Failed to fetch)
# Processing: https://jindal.utdallas.edu/undergraduate-advising/#gsc.tab=0
# Processing: https://jindal.utdallas.edu/undergraduate-advising
# Processing: https://jindal.utdallas.edu/advising/policies/#undergraduate
# Processing: https://jindal.utdallas.edu/undergraduate-programs/fast-track/
# Processing: https://jindal.utdallas.edu/undergraduate-programs/orientation/
# Processing: https://jindal.utdallas.edu/student-resources/scholarships/undergraduate-scholarships/
# Processing: https://jindal.utdallas.edu/student-resources/scholarships/support-fund/
# Processing: https://jindal.utdallas.edu/student-resources/scholarships/graduate-scholarships/
# Processing: https://jindal.utdallas.edu/student-resources/eclat-graduate-fellowship/
# Processing: https://jindal.utdallas.edu/student-resources/scholarships/texas-business-hall-of-fame/
# Processing: https://jindal.utdallas.edu/student-resources/scholarships/student-scholarships/
# Processing: https://jindal.utdallas.edu/jindal/giving-jsom/how-to-give
# Processing: https://jindal.utdallas.edu/giving-jsom/
# Processing: https://jindal.utdallas.edu/giving-jsom/how-to-give/
# Processing: https://jindal.utdallas.edu/giving-jsom/where-to-help/
# Processing: https://jindal.utdallas.edu/alumni-spotlights/masters-in-finance-alumni-spotlights/ian-martinez-class-of-21/
# Processing: https://jindal.utdallas.edu/masters-in-finance-alumni-spotlights
# Processing: https://jindal.utdallas.edu/alumni-spotlights/masters-in-finance-alumni-spotlights/long-ly-class-of-21/
# Processing: https://jindal.utdallas.edu/alumni-spotlights/masters-in-finance-alumni-spotlights/abhishek-sharma-class-of-21/
# Processing: https://jindal.utdallas.edu/alumni-spotlights/masters-in-finance-alumni-spotlights/lester-dsouza-class-of-21/
# Processing: https://jindal.utdallas.edu/the-business-of-healthcare-podcast/episode-95-how-a-surgery-concierge-can-help-healthcare-consumers-make-better-decisions/
# Processing: https://jindal.utdallas.edu/the-business-of-healthcare-podcast
# Processing: https://jindal.utdallas.edu/the-business-of-healthcare-podcast/episode-126-heal-high-school/
# Processing: https://jindal.utdallas.edu/execed/
# Processing: https://jindal.utdallas.edu/execed/emba/
# Processing: https://jindal.utdallas.edu/uncategorized
# Processing: https://jindal.utdallas.edu/uncategorized/ambassador-forms/
# Processing: https://jindal.utdallas.edu/uncategorized/is-a-gmat-or-gre-score-required-to-apply/
# Processing: https://jindal.utdallas.edu/uncategorized/what-is-the-guaranteed-tuition/
# Processing: https://jindal.utdallas.edu/faq/top-questions/what-is-the-required-toefl-or-ielts-score/
# Processing: https://jindal.utdallas.edu/top-questions
# Processing: https://jindal.utdallas.edu/jindal/executive-education/emba/
# Processing: https://jindal.utdallas.edu/author/sarahganbat/
# Processing: https://jindal.utdallas.edu/news/donor-scholarships-launch-brighter-futures-for-jindal-school-students/
# Processing: https://jindal.utdallas.edu/jindal/student-resources/scholarships/
# Processing: https://jindal.utdallas.edu/jindal/student-resources/scholarships/undergraduate-scholarships/
# Processing: https://jindal.utdallas.edu/jindal/student-resources/scholarships/graduate-scholarships/
# Processing: https://jindal.utdallas.edu/mba/academics/full-time-mba/
# Processing: https://jindal.utdallas.edu/rotator/accounting-students-score-scholarships/
# Processing: https://jindal.utdallas.edu/som/accounting/ppa/
# Skipping https://jindal.utdallas.edu/som/accounting/ppa/ (Failed to fetch)
# Processing: https://jindal.utdallas.edu/rotator/big-idea-competition/
# Processing: https://jindal.utdallas.edu/jindal/news/jindal-school-alumna-and-husband-see-success-where-others-see-empty-chairs
# Processing: https://jindal.utdallas.edu/author/jeannespreier/
# Processing: https://jindal.utdallas.edu/news/jindal-school-professor-does-his-part-to-flatten-the-curve-with-his-3d-printer/
# Processing: https://jindal.utdallas.edu/jindal/faculty/bin-hu/
# Skipping https://jindal.utdallas.edu/jindal/faculty/bin-hu/ (Failed to fetch)
# Processing: https://jindal.utdallas.edu/tag/ms-supply-chain-management/
# Processing: https://jindal.utdallas.edu/alumni-spotlights/ms-supply-chain-spotlights/abinav-bayya-academic-transformation/
# Processing: https://jindal.utdallas.edu/tag/inspiration/
# Processing: https://jindal.utdallas.edu/blog/student-spotlight-dena-aljabari/
# Processing: https://jindal.utdallas.edu/honors-programs/nash-leaders-program/
# Processing: https://jindal.utdallas.edu/blog/jsom-jump-starts-fall-2023/
# Processing: https://jindal.utdallas.edu/tag/student-experience/
# Processing: https://jindal.utdallas.edu/news/student-conference-at-the-jindal-school-provides-tools-for-academic-and-career-success/
# Processing: https://jindal.utdallas.edu/jindal/faculty/dawn-owens
# Skipping https://jindal.utdallas.edu/jindal/faculty/dawn-owens (Failed to fetch)
# Processing: https://jindal.utdallas.edu/jindal/undergraduate-programs/
# Processing: https://jindal.utdallas.edu/jindal/student-resources/comet-closet/
# Processing: https://jindal.utdallas.edu/jindal/undergraduate-programs/fast-track/
# Processing: https://jindal.utdallas.edu/jindal/honors-programs/
# Processing: https://jindal.utdallas.edu/honors-programs/dmhp/
# Processing: https://jindal.utdallas.edu/honors-programs/dmhp/incoming-freshmen/
# Processing: https://jindal.utdallas.edu/honors-programs/dmhp/transfer-current-students/
# Processing: https://jindal.utdallas.edu/honors-programs/dmhp/requirements/
# Processing: https://jindal.utdallas.edu/honors-programs/dmhp/cohort-experience/
# Processing: https://jindal.utdallas.edu/honors-programs/dmhp/travel-study-abroad/
# Processing: https://jindal.utdallas.edu/honors-programs/dmhp/faq/
# Processing: https://jindal.utdallas.edu/honors-programs/dmhp/contact/
# Processing: https://jindal.utdallas.edu/jindal/undergraduate-programs/honors-program/prospective-students/requirements/
# Processing: https://jindal.utdallas.edu/jindal/files/2024/08/DMHP_Student_Handbook_2024-25.pdf
# Processing: https://jindal.utdallas.edu/jindal/student-resources/study-abroad-programs/
# Processing: https://jindal.utdallas.edu/jindal/career-management-center/hirejsom/
# Skipping https://jindal.utdallas.edu/jindal/career-management-center/hirejsom/ (Failed to fetch)
# Processing: https://jindal.utdallas.edu/jindal/career-management-center/student-resources-cmc/internship-policies-procedures/#guides
# Processing: https://jindal.utdallas.edu/jindal/career-management-center/faq/#internship
# Processing: https://jindal.utdallas.edu/jindal/career-management-center/faq/#cpt
# Processing: https://jindal.utdallas.edu/career-management-center/recruiting-scams/
# Processing: https://jindal.utdallas.edu/jindal/career-management-center/contact/
# Processing: https://jindal.utdallas.edu/osim/ms-international-management-studies/
# Processing: https://jindal.utdallas.edu/jindal/admission-requirements
# Processing: https://jindal.utdallas.edu/jindal/certificate-programs/
# Processing: https://jindal.utdallas.edu/accounting/masters-degree-options/graduate-certificate-research-foundations/
# Skipping https://jindal.utdallas.edu/accounting/masters-degree-options/graduate-certificate-research-foundations/ (Failed to fetch)
# Processing: https://jindal.utdallas.edu/fin/program-resources/fintech-certificate/
# Skipping https://jindal.utdallas.edu/fin/program-resources/fintech-certificate/ (Failed to fetch)
# Processing: https://jindal.utdallas.edu/fin/program-resources/financial-data-science-certificate/
# Skipping https://jindal.utdallas.edu/fin/program-resources/financial-data-science-certificate/ (Failed to fetch)
# Processing: https://jindal.utdallas.edu/osim/program-resources/healthcare-certificates/lean-six-sigma-yellow-belt/
# Skipping https://jindal.utdallas.edu/osim/program-resources/healthcare-certificates/lean-six-sigma-yellow-belt/ (Failed to fetch)
# Processing: https://jindal.utdallas.edu/infosystems/certificate-programs/applied-machine-learning//
# Skipping https://jindal.utdallas.edu/infosystems/certificate-programs/applied-machine-learning// (Failed to fetch)
# Processing: https://jindal.utdallas.edu/infosystems/certificate-programs/sas-bi-data-mining/
# Skipping https://jindal.utdallas.edu/infosystems/certificate-programs/sas-bi-data-mining/ (Failed to fetch)
# Processing: https://jindal.utdallas.edu/infosystems/certificate-programs/cybersecurity/
# Processing: https://jindal.utdallas.edu/events/low-code-weekend/
# Processing: https://jindal.utdallas.edu/events/low-code-weekend/low-code-weekend-2024/
# Processing: https://jindal.utdallas.edu/cybersecurity-day/
# Processing: https://jindal.utdallas.edu/?page_id=672393
# Skipping https://jindal.utdallas.edu/?page_id=672393 (Failed to fetch)
# Processing: https://jindal.utdallas.edu/events/low-code-weekend-2024/
# Processing: https://jindal.utdallas.edu/osim/ms-innovation-entrepreneurship/certificates/#corporate-innovation
# Processing: https://jindal.utdallas.edu/osim/ms-innovation-entrepreneurship/certificates/#new-venture-entrepreneurship
# Processing: https://jindal.utdallas.edu/execed/product-lifecycle-scm/graduate-certificate/
# Skipping https://jindal.utdallas.edu/execed/product-lifecycle-scm/graduate-certificate/ (Failed to fetch)
# Processing: https://jindal.utdallas.edu/execed/project-management/degree-programs/
# Skipping https://jindal.utdallas.edu/execed/project-management/degree-programs/ (Failed to fetch)
# Processing: https://jindal.utdallas.edu/jindal/centers-of-excellence/iecg/#2
# Processing: https://jindal.utdallas.edu/centers-of-excellence/iecg/events/
# Processing: https://jindal.utdallas.edu/centers-of-excellence/iecg/speakers-iecg/
# Processing: https://jindal.utdallas.edu/centers-of-excellence/iecg/certificates/
# Processing: https://jindal.utdallas.edu/centers-of-excellence/iecg/professional-governance-certificate/
# Processing: https://jindal.utdallas.edu/centers-of-excellence/iecg/advisory-board/
# Processing: https://jindal.utdallas.edu/centers-of-excellence/iecg/sponsors/
# Processing: https://jindal.utdallas.edu/centers-of-excellence/iecg/north-texas-ethics-compliance-council/
# Processing: https://jindal.utdallas.edu/centers-of-excellence/iecg/north-texas-private-equity-council/
# Processing: https://jindal.utdallas.edu/centers-of-excellence/iecg/newsroom/
# Processing: https://jindal.utdallas.edu/centers-of-excellence/iecg/contact/
# Processing: https://jindal.utdallas.edu/jindal/centers-of-excellence/iecg/
# Processing: https://jindal.utdallas.edu/jindal/centers-of-excellence/iecg/certificates/
# Processing: https://jindal.utdallas.edu/jindal/files/2021/02/program_overview_2023_v2.pdf
# Processing: https://jindal.utdallas.edu/jindal/centers-of-excellence/iecg/events
# Processing: https://jindal.utdallas.edu/jindal/files/2021/02/soft-copy-2019-gsem-conference-booklet.pdf
# Processing: https://jindal.utdallas.edu/jindal/files/2021/02/gsem-1905-news-190609.pdf
# Processing: https://jindal.utdallas.edu/jindal/files/2021/02/highly-cited-list-2020-101-bus-econ-2011.pdf
# Processing: https://jindal.utdallas.edu/jindal/centers-of-excellence/iecg/certificates
# Processing: https://jindal.utdallas.edu/jindal/centers-of-excellence/iecg/advisory-board
# Processing: https://jindal.utdallas.edu/jindal/phd-programs/osim-phd-students/
# Processing: https://jindal.utdallas.edu/phd-students/
# Processing: https://jindal.utdallas.edu/phd-programs/accounting-phd-students/
# Processing: https://jindal.utdallas.edu/phd-programs/finance-phd-students/
# Processing: https://jindal.utdallas.edu/phd-programs/information-systems-phd-students/
# Processing: https://jindal.utdallas.edu/phd-programs/marketing-phd-students/
# Processing: https://jindal.utdallas.edu/phd-programs/operations-management-phd-students/
# Processing: https://jindal.utdallas.edu/phd-programs/osim-phd-students/
# Processing: https://jindal.utdallas.edu/jindal/centers-of-excellence/iecg/sponsors
# Processing: https://jindal.utdallas.edu/jindal/centers-of-excellence/iecg/research
# Processing: https://jindal.utdallas.edu/om/ms-scm/capstone-project/
# Skipping https://jindal.utdallas.edu/om/ms-scm/capstone-project/ (Failed to fetch)
# Processing: https://jindal.utdallas.edu/om/program-resources/faculty-research/
# Processing: https://jindal.utdallas.edu/jindal/list-of-published-works/?type=area&area=7
# Skipping https://jindal.utdallas.edu/jindal/list-of-published-works/?type=area&area=7 (Failed to fetch)
# Processing: https://jindal.utdallas.edu/jindal/centers-of-excellence/iecg/contact
# Processing: https://jindal.utdallas.edu/jindal/files/2024/03/IECG-Organization-Overview-1-2f86bf64ca63a2fc.pdf
# Error processing https://jindal.utdallas.edu/jindal/files/2024/03/IECG-Organization-Overview-1-2f86bf64ca63a2fc.pdf: The markup you provided was rejected by the parser. Trying a different parser or a different encoding may help.
#
# Original exception(s) from parser:
#  AssertionError: expected name token at '<![���K\x10W@�G*XB�(�t�'
# Processing: https://jindal.utdallas.edu/jindal/files/2023/11/2023-Membership-Benefits-Flyer-new.pdf
# Processing: https://jindal.utdallas.edu/jindal/files/2024/05/Former-Pro-Cohort-Marketing-Piecev7.pdf
# Processing: https://jindal.utdallas.edu/news/corporate-governance-conference-at-jindal-school-focuses-on-ai-succession-plans-and-entrepreneurial-reinvention/
# Processing: https://jindal.utdallas.edu/jindal/faculty/jackie-kimzey
# Skipping https://jindal.utdallas.edu/jindal/faculty/jackie-kimzey (Failed to fetch)
# Processing: https://jindal.utdallas.edu/faculty/gregg-ballew
# Processing: https://jindal.utdallas.edu/tag/ai/
# Processing: https://jindal.utdallas.edu/news/panel-discussion-at-jindal-school-offers-insights-into-sustainability-careers/
# Processing: https://jindal.utdallas.edu/faculty/dorothee-honhon
# Processing: https://jindal.utdallas.edu/tag/artificial-intelligence/
# Processing: https://jindal.utdallas.edu/news/cybersecurity-day-gives-jindal-school-students-insights-into-profession/
# Processing: https://jindal.utdallas.edu/jindal/the-business-of-healthcare-podcast/episode-119-examining-the-change-healthcare-cyberattack/
# Processing: https://jindal.utdallas.edu/newsletters/jindal-school-now/jindal-school-now-july-2024/
# Processing: https://jindal.utdallas.edu/news/supply-chain-management-programs-at-the-jindal-school-highly-placed-in-industry-experts-ranking/
# Processing: https://jindal.utdallas.edu/jindal/faculty/mark-thouin
# Skipping https://jindal.utdallas.edu/jindal/faculty/mark-thouin (Failed to fetch)
# Processing: https://jindal.utdallas.edu/news/retiring-jindal-school-professor-leaves-lasting-legacy/
# Processing: https://jindal.utdallas.edu/tag/alliance-for-physician-leadership/
# Processing: https://jindal.utdallas.edu/tag/apl/
# ...
#      57             if sub_url.startswith(base_url) and sub_url not in visited_urls:
# ---> 58                 extract_data(sub_url)  # Recursive call
#      59
#      60         time.sleep(1)  # Avoid overwhelming the server
#
# <ipython-input-16-3a85bba8fb00> in extract_data(url)
#      56                 sub_url = base_url + sub_url
#      57             if sub_url.startswith(base_url) and sub_url not in visited_urls:
# ---> 58                 extract_data(sub_url)  # Recursive call
#      59
#      60         time.sleep(1)  # Avoid overwhelming the server
#
# <ipython-input-16-3a85bba8fb00> in extract_data(url)
#      56                 sub_url = base_url + sub_url
#      57             if sub_url.startswith(base_url) and sub_url not in visited_urls:
# ---> 58                 extract_data(sub_url)  # Recursive call
#      59
#      60         time.sleep(1)  # Avoid overwhelming the server
#
# <ipython-input-16-3a85bba8fb00> in extract_data(url)
#      56                 sub_url = base_url + sub_url
#      57             if sub_url.startswith(base_url) and sub_url not in visited_urls:
# ---> 58                 extract_data(sub_url)  # Recursive call
#      59
#      60         time.sleep(1)  # Avoid overwhelming the server
#
# <ipython-input-16-3a85bba8fb00> in extract_data(url)
#      56                 sub_url = base_url + sub_url
#      57             if sub_url.startswith(base_url) and sub_url not in visited_urls:
# ---> 58                 extract_data(sub_url)  # Recursive call
#      59
#      60         time.sleep(1)  # Avoid overwhelming the server
#
# <ipython-input-16-3a85bba8fb00> in extract_data(url)
#      56                 sub_url = base_url + sub_url
#      57             if sub_url.startswith(base_url) and sub_url not in visited_urls:
# ---> 58                 extract_data(sub_url)  # Recursive call
#      59
#      60         time.sleep(1)  # Avoid overwhelming the server
#
# <ipython-input-16-3a85bba8fb00> in extract_data(url)
#      56                 sub_url = base_url + sub_url
#      57             if sub_url.startswith(base_url) and sub_url not in visited_urls:
# ---> 58                 extract_data(sub_url)  # Recursive call
#      59
#      60         time.sleep(1)  # Avoid overwhelming the server
#
# <ipython-input-16-3a85bba8fb00> in extract_data(url)
#      56                 sub_url = base_url + sub_url
#      57             if sub_url.startswith(base_url) and sub_url not in visited_urls:
# ---> 58                 extract_data(sub_url)  # Recursive call
#      59
#      60         time.sleep(1)  # Avoid overwhelming the server
#
# <ipython-input-16-3a85bba8fb00> in extract_data(url)
#      56                 sub_url = base_url + sub_url
#      57             if sub_url.startswith(base_url) and sub_url not in visited_urls:
# ---> 58                 extract_data(sub_url)  # Recursive call
#      59
#      60         time.sleep(1)  # Avoid overwhelming the server
#
# <ipython-input-16-3a85bba8fb00> in extract_data(url)
#      56                 sub_url = base_url + sub_url
#      57             if sub_url.startswith(base_url) and sub_url not in visited_urls:
# ---> 58                 extract_data(sub_url)  # Recursive call
#      59
#      60         time.sleep(1)  # Avoid overwhelming the server
#
# <ipython-input-16-3a85bba8fb00> in extract_data(url)
#      56                 sub_url = base_url + sub_url
#      57             if sub_url.startswith(base_url) and sub_url not in visited_urls:
# ---> 58                 extract_data(sub_url)  # Recursive call
#      59
#      60         time.sleep(1)  # Avoid overwhelming the server
#
# <ipython-input-16-3a85bba8fb00> in extract_data(url)
#      56                 sub_url = base_url + sub_url
#      57             if sub_url.startswith(base_url) and sub_url not in visited_urls:
# ---> 58                 extract_data(sub_url)  # Recursive call
#      59
#      60         time.sleep(1)  # Avoid overwhelming the server
#
# <ipython-input-16-3a85bba8fb00> in extract_data(url)
#      56                 sub_url = base_url + sub_url
#      57             if sub_url.startswith(base_url) and sub_url not in visited_urls:
# ---> 58                 extract_data(sub_url)  # Recursive call
#      59
#      60         time.sleep(1)  # Avoid overwhelming the server
#
# <ipython-input-16-3a85bba8fb00> in extract_data(url)
#      56                 sub_url = base_url + sub_url
#      57             if sub_url.startswith(base_url) and sub_url not in visited_urls:
# ---> 58                 extract_data(sub_url)  # Recursive call
#      59
#      60         time.sleep(1)  # Avoid overwhelming the server
#
# <ipython-input-16-3a85bba8fb00> in extract_data(url)
#      56                 sub_url = base_url + sub_url
#      57             if sub_url.startswith(base_url) and sub_url not in visited_urls:
# ---> 58                 extract_data(sub_url)  # Recursive call
#      59
#      60         time.sleep(1)  # Avoid overwhelming the server
#
# <ipython-input-16-3a85bba8fb00> in extract_data(url)
#      56                 sub_url = base_url + sub_url
#      57             if sub_url.startswith(base_url) and sub_url not in visited_urls:
# ---> 58                 extract_data(sub_url)  # Recursive call
#      59
#      60         time.sleep(1)  # Avoid overwhelming the server
#
# <ipython-input-16-3a85bba8fb00> in extract_data(url)
#      56                 sub_url = base_url + sub_url
#      57             if sub_url.startswith(base_url) and sub_url not in visited_urls:
# ---> 58                 extract_data(sub_url)  # Recursive call
#      59
#      60         time.sleep(1)  # Avoid overwhelming the server
#
# <ipython-input-16-3a85bba8fb00> in extract_data(url)
#      56                 sub_url = base_url + sub_url
#      57             if sub_url.startswith(base_url) and sub_url not in visited_urls:
# ---> 58                 extract_data(sub_url)  # Recursive call
#      59
#      60         time.sleep(1)  # Avoid overwhelming the server
#
# <ipython-input-16-3a85bba8fb00> in extract_data(url)
#      56                 sub_url = base_url + sub_url
#      57             if sub_url.startswith(base_url) and sub_url not in visited_urls:
# ---> 58                 extract_data(sub_url)  # Recursive call
#      59
#      60         time.sleep(1)  # Avoid overwhelming the server
#
# <ipython-input-16-3a85bba8fb00> in extract_data(url)
#      56                 sub_url = base_url + sub_url
#      57             if sub_url.startswith(base_url) and sub_url not in visited_urls:
# ---> 58                 extract_data(sub_url)  # Recursive call
#      59
#      60         time.sleep(1)  # Avoid overwhelming the server
#
# <ipython-input-16-3a85bba8fb00> in extract_data(url)
#      56                 sub_url = base_url + sub_url
#      57             if sub_url.startswith(base_url) and sub_url not in visited_urls:
# ---> 58                 extract_data(sub_url)  # Recursive call
#      59
#      60         time.sleep(1)  # Avoid overwhelming the server
#
# <ipython-input-16-3a85bba8fb00> in extract_data(url)
#      56                 sub_url = base_url + sub_url
#      57             if sub_url.startswith(base_url) and sub_url not in visited_urls:
# ---> 58                 extract_data(sub_url)  # Recursive call
#      59
#      60         time.sleep(1)  # Avoid overwhelming the server
#
# <ipython-input-16-3a85bba8fb00> in extract_data(url)
#      56                 sub_url = base_url + sub_url
#      57             if sub_url.startswith(base_url) and sub_url not in visited_urls:
# ---> 58                 extract_data(sub_url)  # Recursive call
#      59
#      60         time.sleep(1)  # Avoid overwhelming the server
#
# <ipython-input-16-3a85bba8fb00> in extract_data(url)
#      56                 sub_url = base_url + sub_url
#      57             if sub_url.startswith(base_url) and sub_url not in visited_urls:
# ---> 58                 extract_data(sub_url)  # Recursive call
#      59
#      60         time.sleep(1)  # Avoid overwhelming the server
#
# <ipython-input-16-3a85bba8fb00> in extract_data(url)
#      56                 sub_url = base_url + sub_url
#      57             if sub_url.startswith(base_url) and sub_url not in visited_urls:
# ---> 58                 extract_data(sub_url)  # Recursive call
#      59
#      60         time.sleep(1)  # Avoid overwhelming the server
#
# <ipython-input-16-3a85bba8fb00> in extract_data(url)
#      56                 sub_url = base_url + sub_url
#      57             if sub_url.startswith(base_url) and sub_url not in visited_urls:
# ---> 58                 extract_data(sub_url)  # Recursive call
#      59
#      60         time.sleep(1)  # Avoid overwhelming the server
#
# <ipython-input-16-3a85bba8fb00> in extract_data(url)
#      56                 sub_url = base_url + sub_url
#      57             if sub_url.startswith(base_url) and sub_url not in visited_urls:
# ---> 58                 extract_data(sub_url)  # Recursive call
#      59
#      60         time.sleep(1)  # Avoid overwhelming the server
#
# <ipython-input-16-3a85bba8fb00> in extract_data(url)
#      56                 sub_url = base_url + sub_url
#      57             if sub_url.startswith(base_url) and sub_url not in visited_urls:
# ---> 58                 extract_data(sub_url)  # Recursive call
#      59
#      60         time.sleep(1)  # Avoid overwhelming the server
#
# <ipython-input-16-3a85bba8fb00> in extract_data(url)
#      56                 sub_url = base_url + sub_url
#      57             if sub_url.startswith(base_url) and sub_url not in visited_urls:
# ---> 58                 extract_data(sub_url)  # Recursive call
#      59
#      60         time.sleep(1)  # Avoid overwhelming the server
#
# <ipython-input-16-3a85bba8fb00> in extract_data(url)
#      56                 sub_url = base_url + sub_url
#      57             if sub_url.startswith(base_url) and sub_url not in visited_urls:
# ---> 58                 extract_data(sub_url)  # Recursive call
#      59
#      60         time.sleep(1)  # Avoid overwhelming the server
#
# <ipython-input-16-3a85bba8fb00> in extract_data(url)
#      56                 sub_url = base_url + sub_url
#      57             if sub_url.startswith(base_url) and sub_url not in visited_urls:
# ---> 58                 extract_data(sub_url)  # Recursive call
#      59
#      60         time.sleep(1)  # Avoid overwhelming the server
#
# <ipython-input-16-3a85bba8fb00> in extract_data(url)
#      56                 sub_url = base_url + sub_url
#      57             if sub_url.startswith(base_url) and sub_url not in visited_urls:
# ---> 58                 extract_data(sub_url)  # Recursive call
#      59
#      60         time.sleep(1)  # Avoid overwhelming the server
#
# <ipython-input-16-3a85bba8fb00> in extract_data(url)
#      56                 sub_url = base_url + sub_url
#      57             if sub_url.startswith(base_url) and sub_url not in visited_urls:
# ---> 58                 extract_data(sub_url)  # Recursive call
#      59
#      60         time.sleep(1)  # Avoid overwhelming the server
#
# <ipython-input-16-3a85bba8fb00> in extract_data(url)
#      56                 sub_url = base_url + sub_url
#      57             if sub_url.startswith(base_url) and sub_url not in visited_urls:
# ---> 58                 extract_data(sub_url)  # Recursive call
#      59
#      60         time.sleep(1)  # Avoid overwhelming the server
#
# <ipython-input-16-3a85bba8fb00> in extract_data(url)
#      56                 sub_url = base_url + sub_url
#      57             if sub_url.startswith(base_url) and sub_url not in visited_urls:
# ---> 58                 extract_data(sub_url)  # Recursive call
#      59
#      60         time.sleep(1)  # Avoid overwhelming the server
#
# <ipython-input-16-3a85bba8fb00> in extract_data(url)
#      56                 sub_url = base_url + sub_url
#      57             if sub_url.startswith(base_url) and sub_url not in visited_urls:
# ---> 58                 extract_data(sub_url)  # Recursive call
#      59
#      60         time.sleep(1)  # Avoid overwhelming the server
#
# <ipython-input-16-3a85bba8fb00> in extract_data(url)
#      56                 sub_url = base_url + sub_url
#      57             if sub_url.startswith(base_url) and sub_url not in visited_urls:
# ---> 58                 extract_data(sub_url)  # Recursive call
#      59
#      60         time.sleep(1)  # Avoid overwhelming the server
#
# <ipython-input-16-3a85bba8fb00> in extract_data(url)
#      56                 sub_url = base_url + sub_url
#      57             if sub_url.startswith(base_url) and sub_url not in visited_urls:
# ---> 58                 extract_data(sub_url)  # Recursive call
#      59
#      60         time.sleep(1)  # Avoid overwhelming the server
#
# <ipython-input-16-3a85bba8fb00> in extract_data(url)
#      56                 sub_url = base_url + sub_url
#      57             if sub_url.startswith(base_url) and sub_url not in visited_urls:
# ---> 58                 extract_data(sub_url)  # Recursive call
#      59
#      60         time.sleep(1)  # Avoid overwhelming the server
#
# <ipython-input-16-3a85bba8fb00> in extract_data(url)
#      56                 sub_url = base_url + sub_url
#      57             if sub_url.startswith(base_url) and sub_url not in visited_urls:
# ---> 58                 extract_data(sub_url)  # Recursive call
#      59
#      60         time.sleep(1)  # Avoid overwhelming the server
#
# <ipython-input-16-3a85bba8fb00> in extract_data(url)
#      56                 sub_url = base_url + sub_url
#      57             if sub_url.startswith(base_url) and sub_url not in visited_urls:
# ---> 58                 extract_data(sub_url)  # Recursive call
#      59
#      60         time.sleep(1)  # Avoid overwhelming the server
#
# <ipython-input-16-3a85bba8fb00> in extract_data(url)
#      56                 sub_url = base_url + sub_url
#      57             if sub_url.startswith(base_url) and sub_url not in visited_urls:
# ---> 58                 extract_data(sub_url)  # Recursive call
#      59
#      60         time.sleep(1)  # Avoid overwhelming the server
#
# <ipython-input-16-3a85bba8fb00> in extract_data(url)
#      28             return
#      29
# ---> 30         soup = BeautifulSoup(response.text, "html.parser")
#      31
#      32         # Extract Page Title (Main topic)
#
# /usr/local/lib/python3.11/dist-packages/requests/models.py in text(self)
#     929         # Fallback to auto-detected encoding.
#     930         if self.encoding is None:
# --> 931             encoding = self.apparent_encoding
#     932
#     933         # Decode unicode from given encoding.
#
# /usr/local/lib/python3.11/dist-packages/requests/models.py in apparent_encoding(self)
#     791         """The apparent encoding, provided by the charset_normalizer or chardet libraries."""
#     792         if chardet is not None:
# --> 793             return chardet.detect(self.content)["encoding"]
#     794         else:
#     795             # If no character detection library is available, we'll fall back
#
# /usr/local/lib/python3.11/dist-packages/chardet/__init__.py in detect(byte_str, should_rename_legacy)
#      47         byte_str = bytearray(byte_str)
#      48     detector = UniversalDetector(should_rename_legacy=should_rename_legacy)
# ---> 49     detector.feed(byte_str)
#      50     return detector.close()
#      51
#
# /usr/local/lib/python3.11/dist-packages/chardet/universaldetector.py in feed(self, byte_str)
#     272                 self._charset_probers.append(MacRomanProber())
#     273             for prober in self._charset_probers:
# --> 274                 if prober.feed(byte_str) == ProbingState.FOUND_IT:
#     275                     self.result = {
#     276                         "encoding": prober.charset_name,
#
# /usr/local/lib/python3.11/dist-packages/chardet/charsetgroupprober.py in feed(self, byte_str)
#      68             if not prober.active:
#      69                 continue
# ---> 70             state = prober.feed(byte_str)
#      71             if not state:
#      72                 continue
#
# /usr/local/lib/python3.11/dist-packages/chardet/sbcharsetprober.py in feed(self, byte_str)
#     120                         lm_cat = language_model[order][self._last_order]
#     121                     self._seq_counters[lm_cat] += 1
# --> 122             self._last_order = order
#     123
#     124         charset_name = self._model.charset_name
#
# KeyboardInterrupt:
